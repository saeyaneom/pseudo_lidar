# %%
import torch
import torchvision.transforms as transforms
import skimage
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6b670c564e2a> in <module>
# ----> 1 import torch
#       2 import torchvision.transforms as transforms
#       3 import skimage
#       4 from PIL import Image
#
# ModuleNotFoundError: No module named 'torch'

# %%
skimage.io.imread("D:/testing/image_2/1_1_1_20211222_011_00000000.jpg").shape
# Out:
# (1200, 1920, 3)

# %%
img=skimage.io.imread("D:/testing/image_2/1_1_1_20211222_011_00000000.jpg")

# %%
Image.open("D:/testing/image_2/1_1_1_20211222_011_00000000.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1200>

# %%
image_pil = Image.fromarray(img)

# %%
transform = transforms.Compose([
    transforms.Resize(384),  # 모든 이미지를 12 리사이즈           # 텐서로 변환
])

# %%
import numpy as np

# %%
np.array(transform(image_pil)).shape
# Out:
# (384, 614, 3)
