# %% [markdown]
# ## Please first install these libraries
# pip install pythreejs pyntcloud pandas numpy

# %%
from pyntcloud import PyntCloud
import pandas as pd
import os
import numpy as np
import PIL.Image as Image
# %matplotlib inline

# %%
def load_velo_scan(velo_filename):
    scan = np.fromfile(velo_filename, dtype=np.float32)
    scan = scan.reshape((-1, 4))
    return scan

# %%
def paint_points(points, color=[192,0,0]):
    # color = [r, g, b]
    color = np.array([color])
    new_pts = np.zeros([points.shape[0],6])
    new_pts[:,:3] = points
    new_pts[:, 3:] = new_pts[:, 3:] + color
    return new_pts

# %% [markdown]
# ## pseudo-lidar test

# %%
path = 'C:/Users/user/Desktop/saeyan/Dataset/testing/pseudo-lidar_velodyne/000012.bin'
points = load_velo_scan(path)[:,:3]
pd_points = pd.DataFrame(paint_points(points), columns=['x','y','z','red','green','blue'])

# %%
cloud = PyntCloud(pd_points)
cloud.plot(initial_point_size=0.02)
# Out:
# c:\Users\user\.conda\envs\saeyan\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(25.315444056598544, 55.356553972153165, -1.3…
# ...

# %% [markdown]
# ## ground-truth test

# %%
gt_path = "C:/Users/user/Desktop/saeyan/Dataset/testing/velodyne/000012.bin"
points = load_velo_scan(gt_path)[:,:3]
gt_points = pd.DataFrame(paint_points(points), columns=['x','y','z','red','green','blue'])

# %%
gt_cloud = PyntCloud(gt_points)
gt_cloud.plot(initial_point_size=0.02)
# Out:
# C:\Users\user\.conda\envs\saeyan\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(0.22331471608377754, 23.401945390150416, 3.2…
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# 그래프 생성
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

gt_x = gt_points['x'].tolist()
gt_y = gt_points['y'].tolist()
gt_z = gt_points['z'].tolist()

x = pd_points['x'].tolist()
y = pd_points['y'].tolist()
z = pd_points['z'].tolist()


# 3D 산점도 그리기
ax.scatter(gt_x, gt_y, gt_z, color='red', marker='o', alpha=0.1)
ax.scatter(x, y, z, color='blue', marker='o', alpha=0.1)

# 그래프 표시
plt.show()

# %%
gt_cloud.plot(initial_point_size=0.02)
cloud.plot(initial_point_size=0.02)
# Out:
# C:\Users\user\.conda\envs\saeyan\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(0.22331471608377754, 23.401945390150416, 3.2…
# ...
# C:\Users\user\.conda\envs\saeyan\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(25.315444056598544, 55.356553972153165, -1.3…
# ...

# %% [markdown]
# ## sample pseudo-lidar

# %%
sample_path = "C:/Users/user/Desktop/saeyan/Dataset/testing/pseudo-lidar_sample/000012.bin"
sp_points = load_velo_scan(sample_path)[:,:3]
sp_points = pd.DataFrame(paint_points(sp_points), columns=['x','y','z','red','green','blue'])

# %%
sp_cloud = PyntCloud(sp_points)
sp_cloud.plot(initial_point_size=0.02)
# Out:
# c:\Users\user\.conda\envs\saeyan\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(14.295953998411768, 19.573934355212426, 0.51…
# ...

# %%
Image.open("C:/Users/user/Desktop/saeyan/Dataset/testing/image_2/000012.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1242x375 at 0x1E30B981C70>

# %%
with open ("C:/Users/user/Desktop/saeyan/Dataset/testing/pseudo-lidar_velodyne/000012.bin", "rb") as f:
    byte = f.read(size_float*4)
    while byte:
        x,y,z,intensity = struct.unpack("ffff", byte)
        list_pcd.append([x, y, z])
        byte = f.read(size_float*4)
np_pcd = np.asarray(list_pcd)
pcd = o3d.geometry.PointCloud()
v3d = o3d.utility.Vector3dVector
pcd.points = v3d(np_pcd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-23f0ea475ec0> in <module>
#       1 with open ("C:/Users/user/Desktop/saeyan/Dataset/testing/pseudo-lidar_velodyne/000012.bin", "rb") as f:
# ----> 2     byte = f.read(size_float*4)
#       3     while byte:
#       4         x,y,z,intensity = struct.unpack("ffff", byte)
#       5         list_pcd.append([x, y, z])
#
# NameError: name 'size_float' is not defined

# %%
points_arr = np.array(pd_points[["x","y","z"]])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-be36b04c3ba0> in <module>
# ----> 1 import open3d
#
# ModuleNotFoundError: No module named 'open3d'

# %% [markdown]
# ## The expected interface is shown bellow. If you cannot get it, please reopen your web browser.

# %%
Image.open('./pyntcloud.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2162x1390 at 0x7F9F5592BFD0>
